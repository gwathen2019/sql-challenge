# %%
#SQL Alchemy

from sqlalchemy import create_engine
engine = create_engine('postgresql://localhost:5432/SQL_Challenge')
connection = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3c28c2726946> in <module>
#       2
#       3 from sqlalchemy import create_engine
# ----> 4 engine = create_engine('postgresql://localhost:5432/SQL_Challenge')
#       5 connection = engine.connect()
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py in create_engine(*args, **kwargs)
#     433     strategy = kwargs.pop("strategy", default_strategy)
#     434     strategy = strategies.strategies[strategy]
# --> 435     return strategy.create(*args, **kwargs)
#     436
#     437
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py in create(self, name_or_url, **kwargs)
#      85                 if k in kwargs:
#      86                     dbapi_args[k] = pop_kwarg(k)
# ---> 87             dbapi = dialect_cls.dbapi(**dbapi_args)
#      88
#      89         dialect_args["dbapi"] = dbapi
#
# ...

# %%
# Query All Records in the the Database
data = engine.execute("SELECT * FROM SQL_Challenge")

for record in data:
    print(record).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e9b79595680> in <module>
# ----> 1 for record in row:
#       2     print(record).hear()
#
# NameError: name 'row' is not defined
